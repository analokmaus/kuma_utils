# %% [markdown]
# # Tutorial: Data preprocessing

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load UCI Data
# UCI Adult data are going to be used in this tutorial. The data contain both numerical and categorical features, and the target to predict is whether a person makes over 50K a year. It is a very simple binary classification task.

# %%
from catboost.datasets import adult
train, test = adult()

# %%
train.head()
# Out:
#     age         workclass    fnlwgt  education  education-num  \
# 0  39.0         State-gov   77516.0  Bachelors           13.0
# 1  50.0  Self-emp-not-inc   83311.0  Bachelors           13.0
# 2  38.0           Private  215646.0    HS-grad            9.0
# 3  53.0           Private  234721.0       11th            7.0
# 4  28.0           Private  338409.0  Bachelors           13.0
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0        2174.0           0.0            40.0  United-States  <=50K
# 1           0.0           0.0            13.0  United-States  <=50K
# 2           0.0           0.0            40.0  United-States  <=50K
# 3           0.0           0.0            40.0  United-States  <=50K
# 4           0.0           0.0            40.0           Cuba  <=50K

# %%
test.head()
# Out:
#     age  workclass    fnlwgt     education  education-num      marital-status  \
# 0  25.0    Private  226802.0          11th            7.0       Never-married
# 1  38.0    Private   89814.0       HS-grad            9.0  Married-civ-spouse
# 2  28.0  Local-gov  336951.0    Assoc-acdm           12.0  Married-civ-spouse
# 3  44.0    Private  160323.0  Some-college           10.0  Married-civ-spouse
# 4  18.0        NaN  103497.0  Some-college           10.0       Never-married
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male           0.0           0.0
# 1    Farming-fishing      Husband  White    Male           0.0           0.0
# 2    Protective-serv      Husband  White    Male           0.0           0.0
# 3  Machine-op-inspct      Husband  Black    Male        7688.0           0.0
# 4                NaN    Own-child  White  Female           0.0           0.0
#
#    hours-per-week native-country income
# 0            40.0  United-States  <=50K
# 1            50.0  United-States  <=50K
# 2            40.0  United-States   >50K
# 3            40.0  United-States   >50K
# 4            30.0  United-States  <=50K

# %%
target_dict = {
    '<=50K': 0,
    '>50K': 1
}

# %%
train['income'] = train['income'].map(target_dict)
test['income'] = test['income'].map(target_dict)

# %% [markdown]
# ## Encode categorical and numerical features
# For categorical features, label encoding will be applied. For numerical features, standardization will be applied.

# %%
from kuma_utils.preprocessing import (
    PrepPipeline, SelectCategorical, SelectNumerical, DistTransformer)
from sklearn.preprocessing import TargetEncoder, OrdinalEncoder

# %%
num_enc = PrepPipeline([
    SelectNumerical(exclude_cols=['income']),
    DistTransformer('standard')
])

cat_enc = PrepPipeline([
    SelectCategorical(exclude_cols=['income']),
    OrdinalEncoder(encoded_missing_value=np.nan, handle_unknown='use_encoded_value', unknown_value=np.nan)
    # TargetEncoder(),
], target_col='income')

# %%
train_cat, train_num = cat_enc.fit_transform(train).astype(int, errors='ignore'), num_enc.fit_transform(train).astype(float)
categorical_index = list(range(train_cat.shape[1]))
train_encoded = pd.concat([train_cat, train_num], axis=1) 
train_encoded.head()
# Out:
#    workclass  education  marital-status  occupation  relationship  race  sex  \
# 0        6.0        9.0             4.0         0.0           1.0   4.0  1.0
# 1        5.0        9.0             2.0         3.0           0.0   4.0  1.0
# 2        3.0       11.0             0.0         5.0           1.0   4.0  1.0
# 3        3.0        1.0             2.0         5.0           0.0   2.0  1.0
# 4        3.0        9.0             2.0         9.0           5.0   2.0  0.0
#
#    native-country       age    fnlwgt  education-num  capital-gain  \
# 0            38.0  0.030671 -1.063611       1.134739      0.148453
# 1            38.0  0.837109 -1.008707       1.134739     -0.145920
# 2            38.0 -0.042642  0.245079      -0.420060     -0.145920
# 3            38.0  1.057047  0.425801      -1.197459     -0.145920
# 4             4.0 -0.775768  1.408176       1.134739     -0.145920
#
#    capital-loss  hours-per-week
# 0      -0.21666       -0.035429
# 1      -0.21666       -2.222153
# 2      -0.21666       -0.035429
# 3      -0.21666       -0.035429
# 4      -0.21666       -0.035429

# %%
test_encoded = pd.concat([
    cat_enc.transform(test).astype(int, errors='ignore'), 
    num_enc.transform(test).astype(float)], axis=1)
test_encoded.head()
# Out:
#    workclass  education  marital-status  occupation  relationship  race  sex  \
# 0        3.0        1.0             4.0         6.0           3.0   2.0  1.0
# 1        3.0       11.0             2.0         4.0           0.0   4.0  1.0
# 2        1.0        7.0             2.0        10.0           0.0   4.0  1.0
# 3        3.0       15.0             2.0         6.0           0.0   2.0  1.0
# 4        NaN       15.0             4.0         NaN           3.0   4.0  0.0
#
#    native-country       age    fnlwgt  education-num  capital-gain  \
# 0            38.0 -0.995706  0.350774      -1.197459     -0.145920
# 1            38.0 -0.042642 -0.947095      -0.420060     -0.145920
# 2            38.0 -0.775768  1.394362       0.746039     -0.145920
# 3            38.0  0.397233 -0.279070      -0.031360      0.895083
# 4            38.0 -1.508894 -0.817458      -0.031360     -0.145920
#
#    capital-loss  hours-per-week
# 0      -0.21666       -0.035429
# 1      -0.21666        0.774468
# 2      -0.21666       -0.035429
# 3      -0.21666       -0.035429
# 4      -0.21666       -0.845327

# %% [markdown]
# ## Drop data points

# %%
def random_drop(df, ratio=0.1):
    df_drop = df.copy()
    for col in df.columns:
        if col in 'income':
            continue
        drop_num = int(df.shape[0] * ratio)
        drop_idx = np.random.choice(np.arange(df.shape[0]), drop_num)
        df_drop.loc[drop_idx, col] = np.nan
    return df_drop

# %%
train_encoded = random_drop(train_encoded, 0.2)
test_encoded = random_drop(test_encoded, 0.2)
train_dropped = random_drop(train, 0.2)

# %% [markdown]
# ## Regression imputer (LGBMImputer) and Simple imputer

# %%
from kuma_utils.preprocessing.imputer import LGBMImputer
from sklearn.impute import SimpleImputer
import lightgbm as lgb

# %%
train_dropped.head()
# Out:
#     age         workclass    fnlwgt  education  education-num  \
# 0  39.0         State-gov   77516.0  Bachelors           13.0
# 1  50.0  Self-emp-not-inc   83311.0  Bachelors            NaN
# 2  38.0           Private  215646.0        NaN            9.0
# 3  53.0           Private       NaN       11th            7.0
# 4  28.0           Private  338409.0  Bachelors            NaN
#
#        marital-status       occupation   relationship   race     sex  \
# 0       Never-married     Adm-clerical  Not-in-family    NaN    Male
# 1  Married-civ-spouse  Exec-managerial        Husband  White    Male
# 2            Divorced              NaN  Not-in-family  White    Male
# 3  Married-civ-spouse              NaN        Husband  Black    Male
# 4  Married-civ-spouse   Prof-specialty            NaN  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country  income
# 0        2174.0           0.0            40.0            NaN       0
# 1           0.0           0.0            13.0  United-States       0
# 2           0.0           0.0             NaN  United-States       0
# 3           0.0           0.0            40.0  United-States       0
# 4           NaN           0.0            40.0           Cuba       0

# %%
imputer = LGBMImputer(
    fit_params={'num_boost_round': 10}, fit_method='fit', verbose=True)
imputer.fit_transform(train_dropped).head(5)
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]
#     age         workclass         fnlwgt  education  education-num  \
# 0  39.0         State-gov   77516.000000  Bachelors      13.000000
# 1  50.0  Self-emp-not-inc   83311.000000  Bachelors      11.978309
# 2  38.0           Private  215646.000000    HS-grad       9.000000
# 3  53.0           Private  209500.322151       11th       7.000000
# 4  28.0           Private  338409.000000  Bachelors      11.978309
#
#        marital-status       occupation   relationship   race     sex  \
# 0       Never-married     Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse  Exec-managerial        Husband  White    Male
# 2            Divorced     Craft-repair  Not-in-family  White    Male
# 3  Married-civ-spouse     Craft-repair        Husband  Black    Male
# 4  Married-civ-spouse   Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country  income
# 0   2174.000000           0.0       40.000000  United-States       0
# 1      0.000000           0.0       13.000000  United-States       0
# 2      0.000000           0.0       41.773739  United-States       0
# 3      0.000000           0.0       40.000000  United-States       0
# 4    473.331256           0.0       40.000000           Cuba       0

# %%
imputer = LGBMImputer(
    cat_features=categorical_index, 
    fit_params={'num_boost_round': 50, 'callbacks': [lgb.early_stopping(5, verbose=False)]}, 
    fit_method='cv', verbose=True)
train_encoded2 = imputer.fit_transform(train_encoded)
test_encoded2 = imputer.transform(test_encoded)
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]
# /home/hiroshi_yoshihara/.pyenv/versions/anaconda3-2020.02/envs/kumaenv24/lib/python3.10/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(

# %%
simple_imputer = SimpleImputer(strategy='mean')
simple_imputer.fit(train_encoded)
train_encoded3 = pd.DataFrame(simple_imputer.transform(train_encoded), columns=train_encoded.columns)
test_encoded3 = pd.DataFrame(simple_imputer.transform(test_encoded), columns=test_encoded.columns)

# %%
train_encoded2.head()
# Out:
#    workclass  education  marital-status  occupation  relationship  race  sex  \
# 0        3.0        9.0             4.0         0.0           1.0   4.0  1.0
# 1        5.0        9.0             2.0         3.0           0.0   4.0  1.0
# 2        3.0       11.0             0.0         5.0           1.0   4.0  1.0
# 3        3.0        1.0             2.0         5.0           0.0   4.0  1.0
# 4        3.0        9.0             2.0         9.0           5.0   2.0  0.0
#
#    native-country       age    fnlwgt  education-num  capital-gain  \
# 0            38.0  0.030671 -1.063611       1.134739      0.148453
# 1            38.0  0.837109 -1.008707       1.127293     -0.145920
# 2            38.0 -0.042642  0.245079      -0.420060     -0.145920
# 3            38.0  1.057047  0.425801      -1.197459     -0.145920
# 4             4.0 -0.775768  1.408176       1.134739     -0.145920
#
#    capital-loss  hours-per-week
# 0     -0.216660       -0.035429
# 1     -0.216660       -2.222153
# 2     -0.064657       -0.035429
# 3     -0.216660        0.089105
# 4     -0.216660       -0.035429

# %% [markdown]
# ## Compare performance

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from kuma_utils.training import CrossValidator
from kuma_utils.metrics import AUC

# %%
labels = train['income']
test_labels = test['income']

# %%
cv0 = CrossValidator(LogisticRegression)
cv0.train(
    data=(train_encoded3, labels),
    folds=StratifiedKFold(n_splits=5, shuffle=True, random_state=0),
    params={'max_iter': 1000}
)
AUC()(test_labels, np.stack(cv0.smart_predict(test_encoded3)).mean(0))
# Out:
# Logger created at 24/02/14:06:03:47
# 06:03:47 [cv0] Starting fold 0
# eval_metric automatically selected.
# 06:03:48 [None]	best score is 0.821538
# 06:03:48 [cv0] Fold 0: eval=0.821538 (iter=None)
# 06:03:48 [cv0] Starting fold 1
# eval_metric automatically selected.
# 06:03:48 [None]	best score is 0.833625
# 06:03:48 [cv0] Fold 1: eval=0.833625 (iter=None)
# 06:03:48 [cv0] Starting fold 2
# eval_metric automatically selected.
# 06:03:48 [None]	best score is 0.835182
# 06:03:48 [cv0] Fold 2: eval=0.835182 (iter=None)
# 06:03:48 [cv0] Starting fold 3
# eval_metric automatically selected.
# 06:03:48 [None]	best score is 0.832890
# 06:03:48 [cv0] Fold 3: eval=0.832890 (iter=None)
# 06:03:48 [cv0] Starting fold 4
# eval_metric automatically selected.
# 06:03:49 [None]	best score is 0.841778
# 06:03:49 [cv0] Fold 4: eval=0.841778 (iter=None)
# 06:03:49 [cv0] Overall metric: 0.833002 + 0.006536
# 0.8317606206459758

# %%
cv1 = CrossValidator(LogisticRegression)
cv1.train(
    data=(train_encoded2, labels),
    folds=StratifiedKFold(n_splits=5, shuffle=True, random_state=0),
    params={'max_iter': 1000}
)
AUC()(test_labels, np.stack(cv1.smart_predict(test_encoded2)).mean(0))
# Out:
# Logger created at 24/02/14:06:03:51
# 06:03:51 [cv0] Starting fold 0
# eval_metric automatically selected.
# 06:03:52 [None]	best score is 0.837165
# 06:03:52 [cv0] Fold 0: eval=0.837165 (iter=None)
# 06:03:52 [cv0] Starting fold 1
# eval_metric automatically selected.
# 06:03:52 [None]	best score is 0.847400
# 06:03:52 [cv0] Fold 1: eval=0.847400 (iter=None)
# 06:03:52 [cv0] Starting fold 2
# eval_metric automatically selected.
# 06:03:52 [None]	best score is 0.852280
# 06:03:52 [cv0] Fold 2: eval=0.852280 (iter=None)
# 06:03:52 [cv0] Starting fold 3
# eval_metric automatically selected.
# 06:03:53 [None]	best score is 0.851398
# 06:03:53 [cv0] Fold 3: eval=0.851398 (iter=None)
# 06:03:53 [cv0] Starting fold 4
# eval_metric automatically selected.
# 06:03:53 [None]	best score is 0.857892
# 06:03:53 [cv0] Fold 4: eval=0.857892 (iter=None)
# 06:03:53 [cv0] Overall metric: 0.849227 + 0.006898
# 0.8465975438374189

# %% [markdown]
# **LGBMImputer is better than SimpleImputer!**
